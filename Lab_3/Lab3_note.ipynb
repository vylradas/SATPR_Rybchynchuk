# %% [markdown]
# Лабораторна робота 3. Варіант 19.
#
# Додаємо потрібні для виконання завдання пакети. Це є pandas, numpy, prettytable і так далі.

# %%
import pandas as pd
import numpy as np
from prettytable import PrettyTable

# %% [markdown]
# Завдання 2(задача 8). Потрібно побудува таблицю, яка показує який дохід можна отримати при певному попиту та відповідній закупці та спросу.
#
# Створення таблиці та визначення обчислень очікуваного доходу та кінцевого доходу.

# %%
# Функція для побудови дерева рішень та обчислення таблиці
def build_decision_tree(purchases, probabilities, demands):
    table = PrettyTable()
    table.field_names = [
        'Попит', 'Ймовірність', 'Закупка', 'Спрос', 'Продано',
        'Не продано', 'Незадовіл. попит', 'Очікуваний дохід1',
        'Очікуваний дохід2', 'Кінцевий дохід'
    ]

    for purchase in purchases:
        for probability in probabilities:
            for demand in demands:
                if demand >= purchase:
                    sold = purchase
                    not_sold = purchase - sold
                    unsatisfied_demand = 0
                else:
                    sold = demand
                    not_sold = purchase - sold
                    unsatisfied_demand = sold - demand

                expected_income_1 = probability * sold * (2400 - 1500)
                expected_income_2 = sold * (2400 - 1500)
                final_income = expected_income_2 - 1500 * not_sold

                table.add_row([
                    purchase, probability, purchase, demand, sold,
                    not_sold, unsatisfied_demand, expected_income_1,
                    expected_income_2, final_income
                ])

    return table

# %% [markdown]
# Введення початкових за умовою задачі данних та виведення кінцевої таблиці.

# %%
# Вхідні дані
purchases = [20, 15, 10]
probabilities = [0.1, 0.6, 0.3]
demands = [20, 15, 10]

# Побудова таблиці
result_table = build_decision_tree(purchases, probabilities, demands)

# Вивід результату
print("Дерево рішень у вигляді таблиці:")
print(result_table)
# Out:
# Дерево рішень у вигляді таблиці:
# +-------+-------------+---------+-------+---------+------------+------------------+-------------------+-------------------+----------------+
# | Попит | Ймовірність | Закупка | Спрос | Продано | Не продано | Незадовіл. попит | Очікуваний дохід1 | Очікуваний дохід2 | Кінцевий дохід |
# +-------+-------------+---------+-------+---------+------------+------------------+-------------------+-------------------+----------------+
# |   20  |     0.1     |    20   |   20  |    20   |     0      |        0         |       1800.0      |       18000       |     18000      |
# |   20  |     0.1     |    20   |   15  |    15   |     5      |        0         |       1350.0      |       13500       |      6000      |
# |   20  |     0.1     |    20   |   10  |    10   |     10     |        0         |       900.0       |        9000       |     -6000      |
# |   20  |     0.6     |    20   |   20  |    20   |     0      |        0         |      10800.0      |       18000       |     18000      |
